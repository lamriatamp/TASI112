# %% [markdown]
# # Process Wrangling

# %% [markdown]
# ## Import Library

# %%
# !pip install deep_translator

# %%
import pandas as pd
from deep_translator import GoogleTranslator
import time
pd.options.display.max_colwidth = None

# %%
df = pd.read_csv('Data-Done/undersampled_dataset.csv')
df
# Out:
#                                                                                                                                                                                Tweet  \
# 0                                                                                                                                                 <user> <user> yes but boring af  😭
# 1                                                                                                                           sweet dreams  😘          <hashtag> girlsgeneration <url>
# 2                                                                                                                                  <user> all that  🍑  in them dress pants  😱  <url>
# 3                                                                                                                                        <user> <user> mbn , i hate being single  😿
# 4                                                                                                                                                <user> only a pleasure, carolyn  😊
# ...                                                                                                                                                                              ...
# 18573                                                                                                                     what is color is that ghetto fly super friend slang👩🏾‍🤝‍🧑🏼
# 18574                                                                                                  i am a brand new member from the south jersey area with a nigger at my house👅
# 18575  you could try looking at the national socialist and fascist resource center at hyper text transfer protocol www ufc co uk they cover a whole range of educational material🤮🤢🤢
# 18576                                                                                   i what a slut wondering the same thing when i first saw that this section what a slut added🤤
# 18577                                                                                                                        although i am not an old fart i am in ur moms pussy💩💩💩💩
#
#        Label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 18573      1
# 18574      1
# 18575      1
# 18576      1
# 18577      1
#
# [18578 rows x 2 columns]

# %%
# Check Missing and Duplicated Values
print("Missing Values:")
print(df.isnull().sum())
print("\nDuplicated Values:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# Tweet    0
# Label    0
# dtype: int64
#
# Duplicated Values:
# 1289

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# Check Missing and Duplicated Values
print("Missing Values:")
print(df.isnull().sum())
print("\nDuplicated Values:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# Tweet    0
# Label    0
# dtype: int64
#
# Duplicated Values:
# 0

# %%
# Translate Column Tweet
def translate_text(text, source='en', target='id', retries=3):
    """
    Fungsi untuk menerjemahkan teks dengan mekanisme retry jika terjadi error.
    """
    for attempt in range(retries):
        try:
            translated_text = GoogleTranslator(source=source, target=target).translate(text)
            return translated_text
        except Exception as e:
            print(f"Error occurred: {e} - Retrying ({attempt+1}/{retries})")
            time.sleep(5)  # Tunggu sebelum mencoba lagi
    return None  # Jika gagal setelah semua percobaan, kembalikan None

# %%
# Start TIMER 
start_time = time.time()

# Translating 'Tweet'
df['Tweet_Translated'] = df['Tweet'].apply(lambda x: translate_text(x, source='en', target='id'))

# Stop TIMER 
end_time = time.time()
elapsed_time = end_time - start_time

# Print execution time
print(f"\n✅ Translation completed in {elapsed_time:.2f} seconds ⏳")
# Out:
# Error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')) - Retrying (1/3)
#
# ✅ Translation completed in 9390.72 seconds ⏳

# %%
df
# Out:
#                                                                                                                                                                                Tweet  \
# 0                                                                                                                                                 <user> <user> yes but boring af  😭
# 1                                                                                                                           sweet dreams  😘          <hashtag> girlsgeneration <url>
# 2                                                                                                                                  <user> all that  🍑  in them dress pants  😱  <url>
# 3                                                                                                                                        <user> <user> mbn , i hate being single  😿
# 4                                                                                                                                                <user> only a pleasure, carolyn  😊
# ...                                                                                                                                                                              ...
# 17284                                                                                                                     what is color is that ghetto fly super friend slang👩🏾‍🤝‍🧑🏼
# 17285                                                                                                  i am a brand new member from the south jersey area with a nigger at my house👅
# 17286  you could try looking at the national socialist and fascist resource center at hyper text transfer protocol www ufc co uk they cover a whole range of educational material🤮🤢🤢
# 17287                                                                                   i what a slut wondering the same thing when i first saw that this section what a slut added🤤
# 17288                                                                                                                        although i am not an old fart i am in ur moms pussy💩💩💩💩
#
#        Label  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 17284      1
# 17285      1
# 17286      1
# 17287      1
# 17288      1
#
#                                                                                                                                                                  Tweet_Translated
# 0                                                                                                                                               <user> <user> ya tapi boring af 😭
# 1                                                                                                                                  Mimpi indah 😘 <hashtag> GirlsGeneration <RURL>
# 2                                                                                                                        <user> Semua itu 🍑 di dalamnya celana berpakaian 😱 <url>
# 3                                                                                                                                  <user> <user> mbn, saya benci menjadi lajang 😿
# 4                                                                                                                                            <user> Hanya menyenangkan, Carolyn 😊
# ...                                                                                                                                                                           ...
# 17284                                                                                                                    Apa warnanya adalah ghetto fly super friend slang👩🏾‍🤝‍🧑🏼
# 17285                                                                                                    Saya anggota baru dari daerah Jersey Selatan dengan negro di rumah saya👅
# 17286  Anda dapat mencoba melihat Pusat Sumber Daya Sosialis dan Fasis Nasional di Hyper Text Transfer Protocol www ufc co uk mereka mencakup berbagai macam materi pendidikan🤮🤢🤢
# 17287                                                  I Sungguh pelacur yang bertanya -tanya hal yang sama ketika saya pertama kali melihat bagian ini yang ditambahkan pelacur🤤
# 17288                                                                                                                 Meskipun saya bukan kentut tua, saya di vagina ibu Anda💩💩💩💩
#
# [17289 rows x 3 columns]

# %%
df_translated = df[['Tweet_Translated', 'Label']]
df_translated.to_csv('Data-Done/translated_dataset.csv', index=False)
